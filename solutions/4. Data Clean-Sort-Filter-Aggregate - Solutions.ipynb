# %% [markdown]
# # Data Filtering

# %%
import pandas as pd

# %% [markdown]
# # Load Dataset

# %%
ttn = pd.read_csv('../datasets/titanic.csv')
ttn
# Out:
#      PassengerId  Survival  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %% [markdown]
# # Handling missing values
# Missing values in Pandas can be seen as:
# * __NaN__ - __Nan__ - __nan__
# * __Null__ - __null__
# * __NA__ - __na__
#
# Conceptually they all mean a __missing value__.

# %% [markdown]
# ## Identify missing values
#
# __Pandas Methods:__
# * `isnull()`: Returns `True` for __missing values__ (`False` otherwise).
# * `notnull()`: __The inverse of `isnull()`__. Returns `True` for __non-missing values__ (`False` otherwise).
#
# __Note:__ Be aware of the `isna()` and `notna()` methods. They are identical to `isnull()` and `notnull()` respectively.
# <br>
#
# __Examples:__ Testing `isnull()` and `notnull()`

# %%
# Let's test isnull()

ttn.isnull()
# Out:
#      PassengerId  Survival  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# 0    False   True     False
# 1    False  False     False
# 2    False   True     False
# 3    False  False     False
# 4    False   True     False
# ..     ...    ...       ...
# 886  False   True     False
# 887  False  False     False
# 888  False   True     False
# 889  False  False     False
# 890  False   True     False
#
# [891 rows x 12 columns]

# %%
# Let's test notnull()

ttn.notnull()
# Out:
#      PassengerId  Survival  Pclass  Name   Sex    Age  SibSp  Parch  Ticket  \
# 0           True      True    True  True  True   True   True   True    True
# 1           True      True    True  True  True   True   True   True    True
# 2           True      True    True  True  True   True   True   True    True
# 3           True      True    True  True  True   True   True   True    True
# 4           True      True    True  True  True   True   True   True    True
# ..           ...       ...     ...   ...   ...    ...    ...    ...     ...
# 886         True      True    True  True  True   True   True   True    True
# 887         True      True    True  True  True   True   True   True    True
# 888         True      True    True  True  True  False   True   True    True
# 889         True      True    True  True  True   True   True   True    True
# 890         True      True    True  True  True   True   True   True    True
#
#      Fare  Cabin  Embarked
# 0    True  False      True
# 1    True   True      True
# 2    True  False      True
# 3    True   True      True
# 4    True  False      True
# ..    ...    ...       ...
# 886  True  False      True
# 887  True   True      True
# 888  True  False      True
# 889  True   True      True
# 890  True  False      True
#
# [891 rows x 12 columns]

# %% [markdown]
# ## Why/How are these methods useful?
#
# ### 1. Find the number of missing values in each column
#
# __Question:__ Which columns have missing values, and how many?

# %%
# We will use the `sum()` method to find out

ttn.isnull().sum()
# Out:
# PassengerId      0
# Survival         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# #### Why did this work?
# 1. Boolean values (`False` and `True`) are essentially __0__ and __1__ under the hood.
# 2. __Remember:__ `sum()` works in the vertical axis by default (`axis=0`).
#
# So, we count all the `True` occurencies (in our case the __missing values__ since we used `isnull()`)

# %% [markdown]
# ### 2. Filter the rows with missing value in a particular field
#
# __Question:__ Which people are the ones we don't know where they __embarked__ from?

# %%
# Step 1: We want the rows where 'Embarked' is null
# Step 2: We want all the columns for these rows

mask = ttn.loc[: , 'Embarked'].isnull()
ttn.loc[mask , :]
# Out:
#      PassengerId  Survival  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 61   female  38.0      0      0  113572  80.0   B28      NaN
# 829  female  62.0      0      0  113572  80.0   B28      NaN

# %% [markdown]
# ## What should I do about missing values?
#
# There is not a single answer to that.
#
# __It depends on the dataset, the analysis we try to do, the problem we try to solve, etc...__
#
# ### But we have some options

# %% [markdown]
# ### 1. Drop missing values
#
# __Python Method:__ `dropna()`
#
# Allows us to drop rows in respect to missing values.
#
# <br>
#
# __Usecases:__
# * Drop a row if __any__ of the fields is missing.
# * Drop a row if __all__ of the fields are missing.
# * Drop a row if (all or any fields are missing) in a __subset__ of columns.
#
# __Example 1:__ Drop the rows which __any__ of their fields has missing values:

# %%
# Use dropna() to remove rows with how='any'
ttn.dropna(how='any')

# Print the shape of the original dataset

# ttn.shape
# Out:
#      PassengerId  Survival  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 872                           Carlsson, Mr. Frans Olof    male  33.0      0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
#
#      Parch    Ticket     Fare        Cabin Embarked
# 1        0  PC 17599  71.2833          C85        C
# 3        0    113803  53.1000         C123        S
# 6        0     17463  51.8625          E46        S
# 10       1   PP 9549  16.7000           G6        S
# 11       0    113783  26.5500         C103        S
# ..     ...       ...      ...          ...      ...
# 871      1     11751  52.5542          D35        S
# 872      0       695   5.0000  B51 B53 B55        S
# 879      1     11767  83.1583          C50        C
# 887      0    112053  30.0000          B42        S
# 889      0    111369  30.0000         C148        C
#
# [183 rows x 12 columns]

# %% [markdown]
# <br>
#
# __Example 2:__ Drop the rows which __all__ of their fields are missing.

# %%
# Use dropna() to remove rows with how='all'

ttn.dropna(how='all')
# Out:
#      PassengerId  Survival  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %% [markdown]
# <br>
#
# __Example:__ Drop the rows which __any__ of their values are missing, in a __subset__ of columns.

# %%
# Use dropna() to remove rows with how='any' and subset=['Age', 'Embarked']

ttn.dropna(how='any', subset=['Age', 'Embarked'])
# Out:
#      PassengerId  Survival  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 885               Rice, Mrs. William (Margaret Norton)  female  39.0      0
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 885      5            382652  29.1250   NaN        Q
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [712 rows x 12 columns]

# %% [markdown]
# ### 2. Fill in missing values
#
# __Python Method:__ `fillna()`
#
# Fills up the missing values with a given value.
#
# __Example:__ Fill missing __Cabin__ values, with the value `NO_CABIN`

# %%
# Print the value counts of the Cabin - including missing
ttn['Cabin'].value_counts(dropna=False)

# Use fillna() to fill Cabin null values with value='NO_CABIN'
ttn.loc[:, 'Cabin'] = ttn['Cabin'].fillna(value="NO_CABIN")
ttn
# Out:
#      PassengerId  Survival  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare     Cabin Embarked
# 0        0         A/5 21171   7.2500  NO_CABIN        S
# 1        0          PC 17599  71.2833       C85        C
# 2        0  STON/O2. 3101282   7.9250  NO_CABIN        S
# 3        0            113803  53.1000      C123        S
# 4        0            373450   8.0500  NO_CABIN        S
# ..     ...               ...      ...       ...      ...
# 886      0            211536  13.0000  NO_CABIN        S
# 887      0            112053  30.0000       B42        S
# 888      2        W./C. 6607  23.4500  NO_CABIN        S
# 889      0            111369  30.0000      C148        C
# 890      0            370376   7.7500  NO_CABIN        Q
#
# [891 rows x 12 columns]

# %%
# Print the value counts of the Age - including missing
ttn['Age'].value_counts(dropna=False)

# Do the same with Age, but fill in with the average age
ttn.loc[:, 'Age'] = ttn['Age'].fillna(value=ttn['Age'].mean())
ttn
# Out:
#      PassengerId  Survival  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# 886                              Montvila, Rev. Juozas    male  27.000000
# 887                       Graham, Miss. Margaret Edith  female  19.000000
# 888           Johnston, Miss. Catherine Helen "Carrie"  female  29.699118
# 889                              Behr, Mr. Karl Howell    male  26.000000
# 890                                Dooley, Mr. Patrick    male  32.000000
#
#      SibSp  Parch            Ticket     Fare     Cabin Embarked
# 0        1      0         A/5 21171   7.2500  NO_CABIN        S
# 1        1      0          PC 17599  71.2833       C85        C
# 2        0      0  STON/O2. 3101282   7.9250  NO_CABIN        S
# 3        1      0            113803  53.1000      C123        S
# 4        0      0            373450   8.0500  NO_CABIN        S
# ..     ...    ...               ...      ...       ...      ...
# 886      0      0            211536  13.0000  NO_CABIN        S
# 887      0      0            112053  30.0000       B42        S
# 888      1      2        W./C. 6607  23.4500  NO_CABIN        S
# 889      0      0            111369  30.0000      C148        C
# 890      0      0            370376   7.7500  NO_CABIN        Q
#
# [891 rows x 12 columns]

# %%
ttn['Age'].mean()
# Out:
# np.float64(29.69911764705882)

# %% [markdown]
# # Data Sorting

# %%
# Sort values by column 'Age' - ascending/descending

ttn.sort_values(by='Age', ascending=False)
# Out:
#      PassengerId  Survival  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                   Svensson, Mr. Johan
# 96            97         0       1             Goldschmidt, Mr. George B
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 116          117         0       3                  Connors, Mr. Patrick
# ..           ...       ...     ...                                   ...
# 831          832         1       2       Richards, Master. George Sibley
# 469          470         1       3         Baclini, Miss. Helene Barbara
# 644          645         1       3                Baclini, Miss. Eugenie
# 755          756         1       2             Hamalainen, Master. Viljo
# 803          804         1       3       Thomas, Master. Assad Alexander
#
#         Sex    Age  SibSp  Parch    Ticket     Fare     Cabin Embarked
# 630    male  80.00      0      0     27042  30.0000       A23        S
# 851    male  74.00      0      0    347060   7.7750  NO_CABIN        S
# 96     male  71.00      0      0  PC 17754  34.6542        A5        C
# 493    male  71.00      0      0  PC 17609  49.5042  NO_CABIN        C
# 116    male  70.50      0      0    370369   7.7500  NO_CABIN        Q
# ..      ...    ...    ...    ...       ...      ...       ...      ...
# 831    male   0.83      1      1     29106  18.7500  NO_CABIN        S
# 469  female   0.75      2      1      2666  19.2583  NO_CABIN        C
# 644  female   0.75      2      1      2666  19.2583  NO_CABIN        C
# 755    male   0.67      1      1    250649  14.5000  NO_CABIN        S
# 803    male   0.42      0      1      2625   8.5167  NO_CABIN        C
#
# [891 rows x 12 columns]

# %%
# Sort values by more than one columns - ascending & descending

ttn.sort_values(by=['Parch', 'Age'], ascending=[True, False])
# Out:
#      PassengerId  Survival  Pclass  \
# 630          631         1       1
# 851          852         0       3
# 96            97         0       1
# 493          494         0       1
# 116          117         0       3
# ..           ...       ...     ...
# 13            14         0       3
# 610          611         0       3
# 885          886         0       3
# 25            26         1       3
# 678          679         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 630               Barkworth, Mr. Algernon Henry Wilson    male  80.0      0
# 851                                Svensson, Mr. Johan    male  74.0      0
# 96                           Goldschmidt, Mr. George B    male  71.0      0
# 493                            Artagaveytia, Mr. Ramon    male  71.0      0
# 116                               Connors, Mr. Patrick    male  70.5      0
# ..                                                 ...     ...   ...    ...
# 13                         Andersson, Mr. Anders Johan    male  39.0      1
# 610  Andersson, Mrs. Anders Johan (Alfrida Konstant...  female  39.0      1
# 885               Rice, Mrs. William (Margaret Norton)  female  39.0      0
# 25   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0      1
# 678            Goodwin, Mrs. Frederick (Augusta Tyler)  female  43.0      1
#
#      Parch    Ticket     Fare     Cabin Embarked
# 630      0     27042  30.0000       A23        S
# 851      0    347060   7.7750  NO_CABIN        S
# 96       0  PC 17754  34.6542        A5        C
# 493      0  PC 17609  49.5042  NO_CABIN        C
# 116      0    370369   7.7500  NO_CABIN        Q
# ..     ...       ...      ...       ...      ...
# 13       5    347082  31.2750  NO_CABIN        S
# 610      5    347082  31.2750  NO_CABIN        S
# 885      5    382652  29.1250  NO_CABIN        Q
# 25       5    347077  31.3875  NO_CABIN        S
# 678      6   CA 2144  46.9000  NO_CABIN        S
#
# [891 rows x 12 columns]

# %% [markdown]
# # Filtering

# %%
# Get the female passengers that are older than 50 years old

fem = ttn['Sex'] == 'female'
old = ttn['Age'] > 50
ttn.loc[fem & old, :]
# Out:
#      PassengerId  Survival  Pclass  \
# 11            12         1       1
# 15            16         1       2
# 195          196         1       1
# 268          269         1       1
# 275          276         1       1
# 366          367         1       1
# 483          484         1       3
# 496          497         1       1
# 513          514         1       1
# 571          572         1       1
# 591          592         1       1
# 765          766         1       1
# 772          773         0       2
# 774          775         1       2
# 820          821         1       1
# 829          830         1       1
# 879          880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 195                               Lurette, Miss. Elise  female  58.0      0
# 268      Graham, Mrs. William Thompson (Edith Junkins)  female  58.0      0
# 275                  Andrews, Miss. Kornelia Theodosia  female  63.0      1
# 366   Warren, Mrs. Frank Manley (Anna Sophia Atkinson)  female  60.0      1
# 483                             Turkula, Mrs. (Hedwig)  female  63.0      0
# 496                     Eustis, Miss. Elizabeth Mussey  female  54.0      1
# 513     Rothschild, Mrs. Martin (Elizabeth L. Barrett)  female  54.0      1
# 571      Appleton, Mrs. Edward Dale (Charlotte Lamson)  female  53.0      2
# 591    Stephenson, Mrs. Walter Bertram (Martha Eustis)  female  52.0      1
# 765               Hogeboom, Mrs. John C (Anna Andrews)  female  51.0      1
# 772                                  Mack, Mrs. (Mary)  female  57.0      0
# 774              Hocking, Mrs. Elizabeth (Eliza Needs)  female  54.0      1
# 820  Hays, Mrs. Charles Melville (Clara Jennings Gr...  female  52.0      1
# 829          Stone, Mrs. George Nelson (Martha Evelyn)  female  62.0      0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
#
#      Parch       Ticket      Fare     Cabin Embarked
# 11       0       113783   26.5500      C103        S
# 15       0       248706   16.0000  NO_CABIN        S
# 195      0     PC 17569  146.5208       B80        C
# 268      1     PC 17582  153.4625      C125        S
# 275      0        13502   77.9583        D7        S
# 366      0       110813   75.2500       D37        C
# 483      0         4134    9.5875  NO_CABIN        S
# 496      0        36947   78.2667       D20        C
# 513      0     PC 17603   59.4000  NO_CABIN        C
# 571      0        11769   51.4792      C101        S
# 591      0        36947   78.2667       D20        C
# 765      0        13502   77.9583       D11        S
# 772      0  S.O./P.P. 3   10.5000       E77        S
# 774      3        29105   23.0000  NO_CABIN        S
# 820      1        12749   93.5000       B69        S
# 829      0       113572   80.0000       B28      NaN
# 879      1        11767   83.1583       C50        C

# %%
# Get the passengers that are older than 70 years or younger than 1
# and save the result in a new DataFrame

new_df = ttn.loc[ (ttn['Age'] > 70) | (ttn['Age'] < 1) , :] 
new_df
# Out:
#      PassengerId  Survival  Pclass                                  Name  \
# 78            79         1       2         Caldwell, Master. Alden Gates
# 96            97         0       1             Goldschmidt, Mr. George B
# 116          117         0       3                  Connors, Mr. Patrick
# 305          306         1       1        Allison, Master. Hudson Trevor
# 469          470         1       3         Baclini, Miss. Helene Barbara
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 644          645         1       3                Baclini, Miss. Eugenie
# 755          756         1       2             Hamalainen, Master. Viljo
# 803          804         1       3       Thomas, Master. Assad Alexander
# 831          832         1       2       Richards, Master. George Sibley
# 851          852         0       3                   Svensson, Mr. Johan
#
#         Sex    Age  SibSp  Parch    Ticket      Fare    Cabin Embarked
# 78     male   0.83      0      2    248738   29.0000      NaN        S
# 96     male  71.00      0      0  PC 17754   34.6542       A5        C
# 116    male  70.50      0      0    370369    7.7500      NaN        Q
# 305    male   0.92      1      2    113781  151.5500  C22 C26        S
# 469  female   0.75      2      1      2666   19.2583      NaN        C
# 493    male  71.00      0      0  PC 17609   49.5042      NaN        C
# 630    male  80.00      0      0     27042   30.0000      A23        S
# 644  female   0.75      2      1      2666   19.2583      NaN        C
# 755    male   0.67      1      1    250649   14.5000      NaN        S
# 803    male   0.42      0      1      2625    8.5167      NaN        C
# 831    male   0.83      1      1     29106   18.7500      NaN        S
# 851    male  74.00      0      0    347060    7.7750      NaN        S

# %%
# Reset index (drop old index) of new dataframe

new_df.reset_index(inplace=True)
new_df
# Out:
#     index  PassengerId  Survival  Pclass  \
# 0      78           79         1       2
# 1      96           97         0       1
# 2     116          117         0       3
# 3     305          306         1       1
# 4     469          470         1       3
# 5     493          494         0       1
# 6     630          631         1       1
# 7     644          645         1       3
# 8     755          756         1       2
# 9     803          804         1       3
# 10    831          832         1       2
# 11    851          852         0       3
#
#                                     Name     Sex    Age  SibSp  Parch  \
# 0          Caldwell, Master. Alden Gates    male   0.83      0      2
# 1              Goldschmidt, Mr. George B    male  71.00      0      0
# 2                   Connors, Mr. Patrick    male  70.50      0      0
# 3         Allison, Master. Hudson Trevor    male   0.92      1      2
# 4          Baclini, Miss. Helene Barbara  female   0.75      2      1
# 5                Artagaveytia, Mr. Ramon    male  71.00      0      0
# 6   Barkworth, Mr. Algernon Henry Wilson    male  80.00      0      0
# 7                 Baclini, Miss. Eugenie  female   0.75      2      1
# 8              Hamalainen, Master. Viljo    male   0.67      1      1
# 9        Thomas, Master. Assad Alexander    male   0.42      0      1
# 10       Richards, Master. George Sibley    male   0.83      1      1
# 11                   Svensson, Mr. Johan    male  74.00      0      0
#
#       Ticket      Fare    Cabin Embarked
# 0     248738   29.0000      NaN        S
# 1   PC 17754   34.6542       A5        C
# 2     370369    7.7500      NaN        Q
# 3     113781  151.5500  C22 C26        S
# 4       2666   19.2583      NaN        C
# 5   PC 17609   49.5042      NaN        C
# 6      27042   30.0000      A23        S
# 7       2666   19.2583      NaN        C
# 8     250649   14.5000      NaN        S
# 9       2625    8.5167      NaN        C
# 10     29106   18.7500      NaN        S
# 11    347060    7.7750      NaN        S

# %%
# Set PassengerId as Index

new_df = new_df.set_index('PassengerId')
new_df
# Out:
#              index  Survival  Pclass                                  Name  \
# PassengerId
# 79              78         1       2         Caldwell, Master. Alden Gates
# 97              96         0       1             Goldschmidt, Mr. George B
# 117            116         0       3                  Connors, Mr. Patrick
# 306            305         1       1        Allison, Master. Hudson Trevor
# 470            469         1       3         Baclini, Miss. Helene Barbara
# 494            493         0       1               Artagaveytia, Mr. Ramon
# 631            630         1       1  Barkworth, Mr. Algernon Henry Wilson
# 645            644         1       3                Baclini, Miss. Eugenie
# 756            755         1       2             Hamalainen, Master. Viljo
# 804            803         1       3       Thomas, Master. Assad Alexander
# 832            831         1       2       Richards, Master. George Sibley
# 852            851         0       3                   Svensson, Mr. Johan
#
#                 Sex    Age  SibSp  Parch    Ticket      Fare    Cabin Embarked
# PassengerId
# 79             male   0.83      0      2    248738   29.0000      NaN        S
# 97             male  71.00      0      0  PC 17754   34.6542       A5        C
# 117            male  70.50      0      0    370369    7.7500      NaN        Q
# 306            male   0.92      1      2    113781  151.5500  C22 C26        S
# 470          female   0.75      2      1      2666   19.2583      NaN        C
# 494            male  71.00      0      0  PC 17609   49.5042      NaN        C
# 631            male  80.00      0      0     27042   30.0000      A23        S
# 645          female   0.75      2      1      2666   19.2583      NaN        C
# 756            male   0.67      1      1    250649   14.5000      NaN        S
# 804            male   0.42      0      1      2625    8.5167      NaN        C
# 832            male   0.83      1      1     29106   18.7500      NaN        S
# 852            male  74.00      0      0    347060    7.7750      NaN        S

# %% [markdown]
# ---
# # Aggregate Statistics (Groupby)

# %%
# Group-by 'Pclass', display mean of numeric only values
ttn.groupby(['Pclass']).mean(numeric_only=True)
# Out:
#         PassengerId  Survival        Age     SibSp     Parch       Fare
# Pclass
# 1        461.597222  0.629630  38.233441  0.416667  0.356481  84.154687
# 2        445.956522  0.472826  29.877630  0.402174  0.380435  20.662183
# 3        439.154786  0.242363  25.140620  0.615071  0.393075  13.675550
