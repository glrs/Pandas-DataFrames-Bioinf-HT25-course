# %% [markdown]
# ## 1. Import Pandas

# %% [markdown]
# ## 2. Import the Pokemon dataset (pokemon.csv)
# __Note:__ If you get an error, make sure the path to the file is correct.

# %% [markdown]
# ## 3. Show the first 25 entries

# %% [markdown]
# ## 4. Sample 15 random entries

# %% [markdown]
# ## 5. What is the number of observations (rows) in the dataset?

# %% [markdown]
# ## 6. What is the number of features (columns) in the dataset?

# %% [markdown]
# ## 7. Print all the column names.

# %% [markdown]
# ## 8. How is the dataset indexed?
# __In other words:__ Print the index.

# %% [markdown]
# ## 9. What is the data type of each column?

# %% [markdown]
# ## 10. Summarize the DataFrame
# __Note:__ Include both numeric and non-numeric columns in the summary.

# %% [markdown]
# ## 11. Print only the 'Name' and 'HP' columns using `.loc`

# %% [markdown]
# ## 12. Print only the 'Type 1' and 'Legendary' columns using `.iloc`

# %%
pkm.iloc[: , [2,-1] ]

# %% [markdown]
# ---
# # Challenge Exercises (If You Finish Early)

# %% [markdown]
# ### Challenge 1: Print the 'Name', 'Type 1' and 'Attack' columns of the Legendary pokemon

# %% [markdown]
# ### Challenge 2: How many non-Legendary pokemon are there? Also list how many Pokemon per Type 1.

# %% [markdown]
# ### Challenge 3:
# #### Show the `Name`, `Type 1`, and `HP` of all **Fire-type** Pokemon with `HP > 70`, sorted by `HP` descending.

# %% [markdown]
# ### Challenge 4:
# #### Using only `.iloc`, print rows 100 to 110 (_remember `.iloc` is end-exclusive_) and the columns at positions `[0, 1, 5]`.

# %% [markdown]
# ### Challenge 5: New derived column + save CSV

# %% [markdown]
# Create a new column `Power` defined as `Attack + Sp. Atk + Speed`.
# Then show the **top 10** Pokemon by `Power` (print `Name`, `Type 1`, `Power`), and finally, save this table to `top_power.csv` (no index).
